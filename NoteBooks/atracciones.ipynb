# %%
import pandas as pd
import numpy as np
import random

# %%
df_atracciones=pd.read_csv('/Users/h.adrianzabaletahernandez/Desktop/ArchivosCSVProyecto-Pontia2024/atracciones.csv')

# %%
df_atracciones[df_atracciones['id_visitante']==3]
# Out:
#     id_visitante                      t_id                   atraccion  \
# 0              3     Training_10118481.jpg     Montaña Rusa de la Luna
# 1              3     Training_15361067.jpg           Mansión Embrujada
# 2              3     Training_16232328.jpg       Simulador Espacial 3D
# 3              3     Training_27705571.jpg        Fiesta de los Dulces
# 4              3     Training_63766171.jpg            Gran Caída Libre
# 5              3     Training_66555113.jpg         Cine 4D Emocionante
# 6              3     Training_81499267.jpg       Tobogán del Arco Iris
# 7              3     Training_94007493.jpg                Vuelo Mágico
# 8              3     Training_12950225.jpg             Araña Saltarina
# 9              3     Training_42955258.jpg       Tobogán del Arco Iris
# 10             3     Training_50338135.jpg         Cine 4D Emocionante
# 11             3     Training_65820611.jpg     Mundo de las Maravillas
# ...

# %%
df_atracciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_visitante        35887 non-null  int64
#  1   t_id                35887 non-null  object
#  2   atraccion           34749 non-null  object
#  3   comienzo_atraccion  35791 non-null  float64
#  4   tiempo_de_espera    35887 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.4+ MB

# %%
#Podemos eliminarlos?
df_atracciones[(df_atracciones['comienzo_atraccion']<0) | (df_atracciones['atraccion'].isnull()) | (df_atracciones['comienzo_atraccion'].isnull())]
# Out:
#        id_visitante                      t_id                atraccion  \
# 56                4     Training_85932660.jpg                      NaN
# 59                4      Training_1204614.jpg                      NaN
# 60                4     Training_15524948.jpg                      NaN
# 61                4     Training_57944429.jpg                      NaN
# 82                5     Training_81192903.jpg  Barco Pirata Misterioso
# ...             ...                       ...                      ...
# 35801          1735   PublicTest_62426646.jpg                      NaN
# 35815          1741  PrivateTest_23030368.jpg                      NaN
# 35828          1749  PrivateTest_93071746.jpg                      NaN
# 35860          1768   PublicTest_93328347.jpg                      NaN
# 35886          1787   PublicTest_94828377.jpg                      NaN
#
#        comienzo_atraccion  tiempo_de_espera
# 56                  596.0                 4
# ...

# %%
df_atracciones[(df_atracciones['comienzo_atraccion']>15) & (df_atracciones['comienzo_atraccion']<20)]
# Out:
#        id_visitante                      t_id                   atraccion  \
# 63                4     Training_72115626.jpg       Simulador Espacial 3D
# 124               6     Training_12302906.jpg       Caravana de Aventuras
# 226               9     Training_14669195.jpg              Cúpula Estelar
# 472              16     Training_41052937.jpg         Cine 4D Emocionante
# 543              18     Training_45060957.jpg           Circus Fantástico
# ...             ...                       ...                         ...
# 35116          1578   PrivateTest_8115978.jpg             Tren del Terror
# 35159          1586   PublicTest_26383670.jpg  Vuelta al Mundo en 80 Días
# 35450          1636   PublicTest_20014869.jpg       Espejos de la Risueña
# 35559          1659  PrivateTest_61277100.jpg        Montaña del Misterio
# 35835          1753   PublicTest_21175427.jpg         Aventuras Acuáticas
#
#        comienzo_atraccion  tiempo_de_espera
# ...

# %%
df_con_id=df_atracciones.groupby(['atraccion']).agg({'atraccion':'size'})

# %%
df_atracciones.drop(columns=['id_visitante'],inplace=True)
df_atracciones.columns.values.tolist()
# Out:
# ['t_id', 'atraccion', 'comienzo_atraccion', 'tiempo_de_espera']

# %%
df=df_atracciones.groupby(['t_id']).apply(lambda x: x[[ 'atraccion', 'comienzo_atraccion', 'tiempo_de_espera']].to_dict('records')).reset_index().rename(columns={0:'prueba'})
df
# Out:
# /var/folders/z7/nbzy91552pxg2z1dxj_q975w0000gn/T/ipykernel_5401/3962445746.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df=df_atracciones.groupby(['t_id']).apply(lambda x: x[[ 'atraccion', 'comienzo_atraccion', 'tiempo_de_espera']].to_dict('records')).reset_index().rename(columns={0:'prueba'})
#                            t_id  \
# 0      PrivateTest_10072988.jpg
# 1      PrivateTest_10077120.jpg
# 2      PrivateTest_10086748.jpg
# 3      PrivateTest_10089743.jpg
# 4      PrivateTest_10131363.jpg
# ...                         ...
# 35880     Training_99984859.jpg
# 35881     Training_99987906.jpg
# 35882     Training_99988263.jpg
# 35883     Training_99996831.jpg
# ...

# %%
df.isnull().sum()
# Out:
# t_id      0
# prueba    0
# dtype: int64

# %%
df_atracciones.head(5)
# Out:
#    id_visitante                   t_id                atraccion  \
# 0             3  Training_10118481.jpg  Montaña Rusa de la Luna
# 1             3  Training_15361067.jpg        Mansión Embrujada
# 2             3  Training_16232328.jpg    Simulador Espacial 3D
# 3             3  Training_27705571.jpg     Fiesta de los Dulces
# 4             3  Training_63766171.jpg         Gran Caída Libre
#
#    comienzo_atraccion  tiempo_de_espera
# 0               291.0                 5
# 1               180.0                11
# 2               384.0                19
# 3               625.0                 9
# 4               613.0                17

# %%
#Comprobamos que el tiempo de recogida coincide con la cantidad de horas de los datos. EL total de horas son 720.
df_atracciones['comienzo_atraccion'].max()
# Out:
# 719.0

# %%
df_atracciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   t_id                35887 non-null  object
#  1   atraccion           34749 non-null  object
#  2   comienzo_atraccion  35791 non-null  float64
#  3   tiempo_de_espera    35887 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df_atracciones.isnull().sum()
# Out:
# t_id                     0
# atraccion             1138
# comienzo_atraccion      96
# tiempo_de_espera         0
# dtype: int64

# %%
df_atracciones.isna().sum()
# Out:
# t_id                     0
# atraccion             1138
# comienzo_atraccion      96
# tiempo_de_espera         0
# dtype: int64

# %%
t_id=df_atracciones['t_id'].unique()
lista_atracciones=list(t_id)
print(len(lista_atracciones))
# Out:
# 35885

# %%
df_atracciones.head(50)
# Out:
#                         t_id                     atraccion  \
# 0      Training_10118481.jpg       Montaña Rusa de la Luna
# 1      Training_15361067.jpg             Mansión Embrujada
# 2      Training_16232328.jpg         Simulador Espacial 3D
# 3      Training_27705571.jpg          Fiesta de los Dulces
# 4      Training_63766171.jpg              Gran Caída Libre
# 5      Training_66555113.jpg           Cine 4D Emocionante
# 6      Training_81499267.jpg         Tobogán del Arco Iris
# 7      Training_94007493.jpg                  Vuelo Mágico
# 8      Training_12950225.jpg               Araña Saltarina
# 9      Training_42955258.jpg         Tobogán del Arco Iris
# 10     Training_50338135.jpg           Cine 4D Emocionante
# 11     Training_65820611.jpg       Mundo de las Maravillas
# 12      Training_8397060.jpg             Mansión Embrujada
# 13     Training_90069123.jpg         Simulador Espacial 3D
# 14     Training_28136915.jpg             Mansión Embrujada
# ...

# %%
df_atracciones[df_atracciones['atraccion'].isnull()]
# Out:
#                            t_id atraccion  comienzo_atraccion  \
# 56        Training_85932660.jpg       NaN               596.0
# 59         Training_1204614.jpg       NaN               426.0
# 60        Training_15524948.jpg       NaN               100.0
# 61        Training_57944429.jpg       NaN               477.0
# 85        Training_91019189.jpg       NaN               598.0
# ...                         ...       ...                 ...
# 35801   PublicTest_62426646.jpg       NaN               108.0
# 35815  PrivateTest_23030368.jpg       NaN               404.0
# 35828  PrivateTest_93071746.jpg       NaN                80.0
# 35860   PublicTest_93328347.jpg       NaN               562.0
# 35886   PublicTest_94828377.jpg       NaN               417.0
#
#        tiempo_de_espera
# 56                    4
# 59                   21
# 60                    8
# 61                   13
# 85                   17
# ...                 ...
# 35801                13
# ...

# %%
filas_con_nulos = df_atracciones[df_atracciones['atraccion'].isnull() & df_atracciones['comienzo_atraccion'].isnull()]
filas_con_nulos
# Out:
#                           t_id atraccion  comienzo_atraccion  tiempo_de_espera
# 4641     Training_98791138.jpg       NaN                 NaN                 5
# 12219   PublicTest_2067774.jpg       NaN                 NaN                 9
# 13958  PrivateTest_3362951.jpg       NaN                 NaN                14
# 31448  PublicTest_93901885.jpg       NaN                 NaN                 4

# %%
df_atracciones[df_atracciones['comienzo_atraccion'].isnull()]
# Out:
#                            t_id                atraccion  comienzo_atraccion  \
# 82        Training_81192903.jpg  Barco Pirata Misterioso                 NaN
# 386       Training_10333072.jpg       Carrusel Encantado                 NaN
# 1280      Training_13081724.jpg       Cohetes Galácticos                 NaN
# 2445      Training_67457164.jpg          Tren del Terror                 NaN
# 2630      Training_60936737.jpg       Cohetes Galácticos                 NaN
# ...                         ...                      ...                 ...
# 34558     Training_98381187.jpg       Carrusel Encantado                 NaN
# 34915  PrivateTest_56190110.jpg        Circus Fantástico                 NaN
# 35076     Training_73211625.jpg        Circus Fantástico                 NaN
# 35258  PrivateTest_39819887.jpg      Torbellino Espacial                 NaN
# 35548  PrivateTest_23899463.jpg          Selva Encantada                 NaN
#
#        tiempo_de_espera
# ...

# %%
df_atracciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   t_id                35887 non-null  object
#  1   atraccion           34749 non-null  object
#  2   comienzo_atraccion  35791 non-null  float64
#  3   tiempo_de_espera    35887 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
#Vamos a sustituir los valores nulos de la columnna comienzo de atracción. Y los valores que superen el tiempo de toma de los datos.
#Para ello crearemos una lista aleatoria con el total del tiempo - 1 de los datos
#utilizamos un bucle for con una selección aleatoria para sustituir los valores nulos. 
tiempo = [random.randint(1, 704) for i in range(96)]
for i in range(len(df_atracciones)):
    if pd.isnull(df_atracciones.loc[i,'comienzo_atraccion']):
         df_atracciones.loc[i, 'comienzo_atraccion'] = random.choice(tiempo)
    if df_atracciones.loc[i,'comienzo_atraccion']>705:
         df_atracciones.loc[i, 'comienzo_atraccion'] = random.choice(tiempo)

# %%
df_atracciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   t_id                35887 non-null  object
#  1   atraccion           34749 non-null  object
#  2   comienzo_atraccion  35887 non-null  float64
#  3   tiempo_de_espera    35887 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
#Estamos creando una lista con las atracciones.
atr=df_atracciones['atraccion'].unique()
lista_atracciones=list(atr)
lista_atracciones = [x for x in lista_atracciones if pd.notna(x)]
#lista_atracciones.pop()#una solución un poco chapucera. No entiendo porque no me funciona lo de arriba.

# %%
lista_atracciones
# Out:
# ['Montaña Rusa de la Luna',
#  'Mansión Embrujada',
#  'Simulador Espacial 3D',
#  'Fiesta de los Dulces',
#  'Gran Caída Libre',
#  'Cine 4D Emocionante',
#  'Tobogán del Arco Iris',
#  'Vuelo Mágico',
#  'Araña Saltarina',
#  'Mundo de las Maravillas',
#  'Cohetes Galácticos',
#  'Safari Salvaje',
#  'Barco Pirata Misterioso',
#  'Montaña del Misterio',
#  'Selva Encantada',
#  'Jardín de las Hadas',
#  'Espejos de la Risueña',
#  'Laberinto de Sueños',
#  'Dragón Volador',
#  'Carros Chocones Divertidos',
#  'Carrusel Encantado',
#  'Viaje al Centro de la Tierra',
#  'Caravana de Aventuras',
#  'Cascada Encantada',
#  'Carrera de Autos Locos',
#  'Rápido del Trueno',
#  'Vuelta al Mundo en 80 Días',
#  'Cúpula Estelar',
#  'Circuito Veloz',
#  nan,
#  'Aventuras Acuáticas',
#  'Tirolina Extrema',
#  'Circus Fantástico',
#  'Torbellino Espacial',
#  'Rueda de la Fortuna',
#  'Tren del Terror']

# %%
#Vamos a susutituir los valores nulos de la columna atracción mediante una selección aleatoria,
#para ello utilizaremos un bucle for. Utilizaremos la lista creada anteriormente.
for i in range(len(df_atracciones)):
    if pd.isnull(df_atracciones.loc[i, 'atraccion']):
        df_atracciones.loc[i, 'atraccion'] = random.choice(lista_atracciones)

# %%
#De esta manera quitamos el valor str "nan" que se nos quedó de la interación anterior, al no haber eliminado "nan" de la lista.
df_atracciones['atraccion'] = df_atracciones['atraccion'].replace("nan", random.choice(lista_atracciones))

# %%
df_sin_nulos=df_atracciones.groupby(['atraccion']).agg({'atraccion':'size'})

# %%
df_sin_nulos
# Out:
#                               atraccion
# atraccion
# Araña Saltarina                    1026
# Aventuras Acuáticas                1048
# Barco Pirata Misterioso            1025
# Caravana de Aventuras              1009
# Carrera de Autos Locos             1024
# Carros Chocones Divertidos         1039
# Carrusel Encantado                  989
# Cascada Encantada                  1003
# Cine 4D Emocionante                1015
# Circuito Veloz                     1021
# Circus Fantástico                  1055
# Cohetes Galácticos                 1020
# Cúpula Estelar                     1018
# Dragón Volador                     1016
# Espejos de la Risueña              1001
# Fiesta de los Dulces               1035
# Gran Caída Libre                   1007
# Jardín de las Hadas                1027
# Laberinto de Sueños                1029
# Mansión Embrujada                  1056
# Montaña Rusa de la Luna            1044
# Montaña del Misterio               1008
# ...

# %%
df_atracciones['comienzo_atraccion']=df_atracciones['comienzo_atraccion'].abs()

# %%
df_atracciones[df_atracciones['atraccion'].isnull()]
# Out:
# Empty DataFrame
# Columns: [t_id, atraccion, comienzo_atraccion, tiempo_de_espera]
# Index: []

# %%
df_atracciones.to_csv('atracciones_sql.csv', index=False)

# %%
df_atracciones[df_atracciones['t_id']=='PrivateTest_88305.jpg']
# Out:
#                         t_id       atraccion  comienzo_atraccion  \
# 33882  PrivateTest_88305.jpg  Circuito Veloz                 1.0
#
#        tiempo_de_espera
# 33882                13

# %%
df_atracciones.head(20)
# Out:
#                      t_id                atraccion  comienzo_atraccion  \
# 0   Training_10118481.jpg  Montaña Rusa de la Luna               291.0
# 1   Training_15361067.jpg        Mansión Embrujada               180.0
# 2   Training_16232328.jpg    Simulador Espacial 3D               384.0
# 3   Training_27705571.jpg     Fiesta de los Dulces               625.0
# 4   Training_63766171.jpg         Gran Caída Libre               613.0
# 5   Training_66555113.jpg      Cine 4D Emocionante               533.0
# 6   Training_81499267.jpg    Tobogán del Arco Iris               297.0
# 7   Training_94007493.jpg             Vuelo Mágico                82.0
# 8   Training_12950225.jpg          Araña Saltarina               316.0
# 9   Training_42955258.jpg    Tobogán del Arco Iris               552.0
# 10  Training_50338135.jpg      Cine 4D Emocionante               417.0
# 11  Training_65820611.jpg  Mundo de las Maravillas               698.0
# ...

# %%
df_atracciones_2=pd.read_csv("/Users/h.adrianzabaletahernandez/Desktop/ArchivosCSVProyecto-Pontia2024/atracciones_sql.csv")

# %%
# Agrupar fotos por combinación de 'atraccion', 'comienzo_atraccion' y 'tiempo_de_espera'
grupo_fotos = df_atracciones_2.groupby(['atraccion', 'comienzo_atraccion', 'tiempo_de_espera'])['t_id'].apply(list).reset_index()
#['t_id'].apply(list): Convierte los identificadores de foto en listas para cada grupo.
# Mostrar el resultado
grupo_fotos.sample(50)
# Out:
#                           atraccion  comienzo_atraccion  tiempo_de_espera  \
# 776                 Araña Saltarina               537.0                13
# 17186           Jardín de las Hadas               452.0                 7
# 29566           Torbellino Espacial               207.0                13
# 5709     Carros Chocones Divertidos               581.0                 8
# 32616                  Vuelo Mágico               363.0                17
# 24199             Rápido del Trueno               516.0                10
# 21721       Mundo de las Maravillas               209.0                 9
# 22886           Rueda de la Fortuna               300.0                12
# 6425             Carrusel Encantado               404.0                13
# 32164                  Vuelo Mágico                24.0                17
# 24666                Safari Salvaje               135.0                10
# 9337                 Circuito Veloz               419.0                12
# ...
