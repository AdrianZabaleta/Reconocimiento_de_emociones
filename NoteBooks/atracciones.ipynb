# %%
import pandas as pd

# %%
df_atracciones=pd.read_csv('/Users/h.adrianzabaletahernandez/Desktop/ReconocimientoDeEmociones/Archivos CSV/atracciones.csv')
df_atracciones.drop(columns=['id_visitante'],inplace=True)

# %%
df_atracciones.sample(10)
# Out:
#                            t_id                     atraccion  \
# 14578     Training_63637868.jpg            Cohetes Galácticos
# 31888     Training_57077391.jpg  Viaje al Centro de la Tierra
# 6268      Training_39054521.jpg  Viaje al Centro de la Tierra
# 17263     Training_37587759.jpg         Espejos de la Risueña
# 29600     Training_68111950.jpg                Circuito Veloz
# 14904  PrivateTest_99344090.jpg  Viaje al Centro de la Tierra
# 12674     Training_42541053.jpg               Tren del Terror
# 12884     Training_76746482.jpg                  Vuelo Mágico
# 5270      Training_11514199.jpg           Cine 4D Emocionante
# 10856     Training_78512361.jpg           Torbellino Espacial
#
#        comienzo_atraccion  tiempo_de_espera
# 14578               157.0                15
# 31888               271.0                17
# 6268                445.0                16
# 17263               704.0                10
# 29600                31.0                15
# ...

# %%
#Comprobamos que el tiempo de recogida coincide con la cantidad de horas de los datos. EL total de horas son 720.
df_atracciones['comienzo_atraccion'].max()
# Out:
# 719.0

# %%
df_atracciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35887 entries, 0 to 35886
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   t_id                35887 non-null  object
#  1   atraccion           34749 non-null  object
#  2   comienzo_atraccion  35791 non-null  float64
#  3   tiempo_de_espera    35887 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df_atracciones.isnull().sum()
# Out:
# t_id                     0
# atraccion             1138
# comienzo_atraccion      96
# tiempo_de_espera         0
# dtype: int64

# %%
df_atracciones.isna().sum()
# Out:
# t_id                     0
# atraccion             1138
# comienzo_atraccion      96
# tiempo_de_espera         0
# dtype: int64

# %%
df_atracciones.head(50)

# %%
df_atracciones[df_atracciones['atraccion'].isnull()]
# Out:
#                            t_id atraccion  comienzo_atraccion  \
# 56        Training_85932660.jpg       NaN               596.0
# 59         Training_1204614.jpg       NaN               426.0
# 60        Training_15524948.jpg       NaN               100.0
# 61        Training_57944429.jpg       NaN               477.0
# 85        Training_91019189.jpg       NaN               598.0
# ...                         ...       ...                 ...
# 35801   PublicTest_62426646.jpg       NaN               108.0
# 35815  PrivateTest_23030368.jpg       NaN               404.0
# 35828  PrivateTest_93071746.jpg       NaN                80.0
# 35860   PublicTest_93328347.jpg       NaN               562.0
# 35886   PublicTest_94828377.jpg       NaN               417.0
#
#        tiempo_de_espera
# 56                    4
# 59                   21
# 60                    8
# 61                   13
# 85                   17
# ...                 ...
# 35801                13
# ...

# %%
filas_con_nulos = df_atracciones[df_atracciones['atraccion'].isnull() & df_atracciones['comienzo_atraccion'].isnull()]
filas_con_nulos
# Out:
#                           t_id atraccion  comienzo_atraccion  tiempo_de_espera
# 4641     Training_98791138.jpg       NaN                 NaN                 5
# 12219   PublicTest_2067774.jpg       NaN                 NaN                 9
# 13958  PrivateTest_3362951.jpg       NaN                 NaN                14
# 31448  PublicTest_93901885.jpg       NaN                 NaN                 4

# %%
df_atracciones[df_atracciones['comienzo_atraccion'].isnull()]
# Out:
#                            t_id                atraccion  comienzo_atraccion  \
# 82        Training_81192903.jpg  Barco Pirata Misterioso                 NaN
# 386       Training_10333072.jpg       Carrusel Encantado                 NaN
# 1280      Training_13081724.jpg       Cohetes Galácticos                 NaN
# 2445      Training_67457164.jpg          Tren del Terror                 NaN
# 2630      Training_60936737.jpg       Cohetes Galácticos                 NaN
# ...                         ...                      ...                 ...
# 34558     Training_98381187.jpg       Carrusel Encantado                 NaN
# 34915  PrivateTest_56190110.jpg        Circus Fantástico                 NaN
# 35076     Training_73211625.jpg        Circus Fantástico                 NaN
# 35258  PrivateTest_39819887.jpg      Torbellino Espacial                 NaN
# 35548  PrivateTest_23899463.jpg          Selva Encantada                 NaN
#
#        tiempo_de_espera
# ...
